# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
# Out:
# Using Theano backend.

# %%
dataset = read_csv('../Datasets/fashion-mnist-test.csv')
dataset = dataset.values

# %%
for i in range(10):
    plt.figure()
    plt.imshow(dataset[i,1:].reshape(28,28), cmap='gray')

# %%
X, y = dataset[:, 1:]/255, dataset[:, 0]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
y_train.shape, y_test.shape
# Out:
# ((8000,), (2000,))

# %%
y_train = np_utils.to_categorical(y_train)
y_test  = np_utils.to_categorical(y_test)

# %%
y_train.shape, y_test.shape
# Out:
# ((8000, 10), (2000, 10))

# %%
model = Sequential()

model.add(Dense(256, input_shape=(784,)))
model.add(Activation('sigmoid'))

model.add(Dense(64))
model.add(Activation('tanh'))

model.add(Dense(10))
model.add(Activation('softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               200960
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# activation_2 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 218,058
# Trainable params: 218,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Initialize Weights
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
hist = model.fit(X_train, y_train,
          shuffle=True,
          epochs=40,
          batch_size=128,
          validation_data=(X_test, y_test)
         )
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 2.1979 - acc: 0.2911 - val_loss: 2.0610 - val_acc: 0.4810
# Epoch 2/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 1.9594 - acc: 0.4841 - val_loss: 1.8556 - val_acc: 0.5185
# Epoch 3/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 1.7681 - acc: 0.5460 - val_loss: 1.6779 - val_acc: 0.5550
# Epoch 4/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 1.6059 - acc: 0.5805 - val_loss: 1.5308 - val_acc: 0.5875
# Epoch 5/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 1.4740 - acc: 0.6089 - val_loss: 1.4125 - val_acc: 0.6090
# Epoch 6/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 1.3683 - acc: 0.6315 - val_loss: 1.3172 - val_acc: 0.6455
# Epoch 7/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 1.2836 - acc: 0.6519 - val_loss: 1.2414 - val_acc: 0.6605
# Epoch 8/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 1.2133 - acc: 0.6675 - val_loss: 1.1777 - val_acc: 0.6535
# Epoch 9/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 1.1557 - acc: 0.6764 - val_loss: 1.1264 - val_acc: 0.6850
# Epoch 10/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 1.1065 - acc: 0.6909 - val_loss: 1.0776 - val_acc: 0.6815
# Epoch 11/40
# 8000/8000 [==============================] - 0s 22us/step - loss: 1.0644 - acc: 0.6951 - val_loss: 1.0383 - val_acc: 0.6945
# Epoch 12/40
# 8000/8000 [==============================] - 0s 23us/step - loss: 1.0270 - acc: 0.7001 - val_loss: 1.0037 - val_acc: 0.6980
# Epoch 13/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 0.9944 - acc: 0.7100 - val_loss: 0.9725 - val_acc: 0.7100
# Epoch 14/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 0.9647 - acc: 0.7126 - val_loss: 0.9457 - val_acc: 0.7150
# Epoch 15/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 0.9385 - acc: 0.7176 - val_loss: 0.9204 - val_acc: 0.7180
# Epoch 16/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 0.9142 - acc: 0.7229 - val_loss: 0.8983 - val_acc: 0.7120
# Epoch 17/40
# 8000/8000 [==============================] - 0s 22us/step - loss: 0.8922 - acc: 0.7270 - val_loss: 0.8777 - val_acc: 0.7185
# Epoch 18/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 0.8721 - acc: 0.7280 - val_loss: 0.8581 - val_acc: 0.7285
# Epoch 19/40
# 8000/8000 [==============================] - 0s 22us/step - loss: 0.8537 - acc: 0.7318 - val_loss: 0.8411 - val_acc: 0.7220
# Epoch 20/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 0.8365 - acc: 0.7329 - val_loss: 0.8246 - val_acc: 0.7340
# Epoch 21/40
# 8000/8000 [==============================] - 0s 22us/step - loss: 0.8204 - acc: 0.7392 - val_loss: 0.8112 - val_acc: 0.7305
# Epoch 22/40
# 8000/8000 [==============================] - 0s 24us/step - loss: 0.8061 - acc: 0.7378 - val_loss: 0.7962 - val_acc: 0.7305
# Epoch 23/40
# 8000/8000 [==============================] - 0s 23us/step - loss: 0.7927 - acc: 0.7415 - val_loss: 0.7829 - val_acc: 0.7355
# Epoch 24/40
# 8000/8000 [==============================] - 0s 23us/step - loss: 0.7796 - acc: 0.7448 - val_loss: 0.7707 - val_acc: 0.7375
# Epoch 25/40
# 8000/8000 [==============================] - 0s 23us/step - loss: 0.7676 - acc: 0.7475 - val_loss: 0.7596 - val_acc: 0.7410
# Epoch 26/40
# 8000/8000 [==============================] - 0s 23us/step - loss: 0.7568 - acc: 0.7476 - val_loss: 0.7490 - val_acc: 0.7385
# Epoch 27/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 0.7463 - acc: 0.7506 - val_loss: 0.7391 - val_acc: 0.7440
# Epoch 28/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 0.7363 - acc: 0.7534 - val_loss: 0.7299 - val_acc: 0.7390
# Epoch 29/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 0.7265 - acc: 0.7550 - val_loss: 0.7216 - val_acc: 0.7450
# Epoch 30/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 0.7182 - acc: 0.7546 - val_loss: 0.7144 - val_acc: 0.7465
# Epoch 31/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 0.7102 - acc: 0.7595 - val_loss: 0.7046 - val_acc: 0.7480
# Epoch 32/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 0.7023 - acc: 0.7586 - val_loss: 0.6996 - val_acc: 0.7505
# Epoch 33/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 0.6946 - acc: 0.7648 - val_loss: 0.6929 - val_acc: 0.7535
# Epoch 34/40
# 8000/8000 [==============================] - 0s 23us/step - loss: 0.6876 - acc: 0.7642 - val_loss: 0.6859 - val_acc: 0.7550
# Epoch 35/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 0.6809 - acc: 0.7668 - val_loss: 0.6801 - val_acc: 0.7560
# Epoch 36/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 0.6747 - acc: 0.7692 - val_loss: 0.6729 - val_acc: 0.7565
# Epoch 37/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 0.6683 - acc: 0.7701 - val_loss: 0.6670 - val_acc: 0.7560
# Epoch 38/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 0.6626 - acc: 0.7720 - val_loss: 0.6640 - val_acc: 0.7630
# Epoch 39/40
# 8000/8000 [==============================] - 0s 21us/step - loss: 0.6569 - acc: 0.7730 - val_loss: 0.6580 - val_acc: 0.7600
# Epoch 40/40
# 8000/8000 [==============================] - 0s 20us/step - loss: 0.6517 - acc: 0.7738 - val_loss: 0.6516 - val_acc: 0.7635

# %%
hist.history.keys()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
plt.figure(0)
plt.title("Loss")
plt.plot(hist.history['loss'], 'r', label='Training')
plt.plot(hist.history['val_loss'], 'b', label='Testing')
plt.legend()
plt.show()

plt.figure(1)
plt.title("Accuracy")
plt.plot(hist.history['acc'], 'r', label='Training')
plt.plot(hist.history['val_acc'], 'b', label='Testing')
plt.legend()
plt.show()
